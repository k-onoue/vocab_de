# %% [markdown]
# https://chat.openai.com/c/340122ee-c20a-49c1-8d58-a0487fc44ce1
#
# https://huggingface.co/padmalcom/tts-tacotron2-german
#
# tts 調べたら色々ありそう

# %%
from gtts import gTTS
from IPython.display import Audio

text = "Guten Tag! Wie geht es Ihnen?"
language = "de"

tts = gTTS(text=text, lang=language, slow=False)
tts.save("./../audios/sample_output.mp3")

Audio("./../audios/sample_output.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio, display

# text = "Guten Tag! Wie geht es Ihnen?"
text = "Ich werde das Paket aus der Post holen."
language = "de"

tts = gTTS(text=text, lang=language, slow=False)

# Save the generated speech to a temporary file
# tts.save("output.mp3")

# Display the audio directly in the notebook
display(Audio("output.mp3", autoplay=True))
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
! pip install pydub

# %%
from gtts import gTTS
from pydub import AudioSegment
from pydub.playback import play

text = "Guten Tag! Wie geht es Ihnen?"
language = "de"

# Generate speech with gTTS
tts = gTTS(text=text, lang=language, slow=False)
tts.save("output.mp3")

# Load the generated speech using pydub
audio = AudioSegment.from_file("output.mp3")

# Change the speed to 1.25x
speed_multiplier = 1.25
audio = audio.speedup(playback_speed=speed_multiplier)

# Save the modified audio
audio.export("output_speedup.mp3", format="mp3")

# Play the modified audio
play(audio)

# %%
import pandas as pd
pd.set_option("display.max_colwidth", 999)
pd.set_option("display.max_row", 999)

# %% [markdown]
# # 第１部 基本五を比べてみよう
#
# ## [A] 初級文法に必要な単語
#
# ### 冠詞、代名詞

# %%
data = [
    ['der', 'Nominative', 'Der Hund ist groß.', '犬は大きいです。'],
    ['der', 'Genitive', 'Das ist das Auto der Lehrerin.', 'これは先生の車です。'],
    ['der', 'Dative', 'Ich gebe das Buch der Freundin.', '私は友達にその本を渡します。'],
    ['der', 'Accusative', 'Ich sehe den Mann.', '私はその男性を見ています。']
] + [
    ['die', 'Nominative', 'Die Blumen sind schön.', '花は美しいです。'],
    ['die', 'Genitive', 'Das ist das Haus der Familie.', 'これは家族の家です。'],
    ['die', 'Dative', 'Ich gebe die Schokolade der Freundin.', '私は友達にそのチョコレートを渡します。'],
    ['die', 'Accusative', 'Ich sehe die Katze.', '私はその猫を見ています。']
] + [
    ['das', 'Nominative', 'Das Buch ist interessant.', 'その本は面白いです。'],
    ['das', 'Genitive', 'Das ist das Auto des Mannes.', 'これはその男性の車です。'],
    ['das', 'Dative', 'Ich gebe das Geld dem Kind.', '私はそのお金を子供に渡します。'],
    ['das', 'Accusative', 'Ich sehe das Mädchen.', '私はその少女を見ています。']
] + [
    ['die', 'Nominative', 'Die Kinder spielen im Garten.', '子供たちは庭で遊んでいます。'],
    ['der', 'Genitive', 'Das sind die Spielzeuge der Kinder.', 'これは子供たちのおもちゃです。'],
    ['den', 'Dative', 'Ich gebe den Kindern Süßigkeiten.', '私は子供たちにお菓子をあげます。'],
    ['die', 'Accusative', 'Ich sehe die Kinder.', '私は子供たちを見ています。']
] + [
    ['ein', 'Nominative', 'Ein Mann geht spazieren.', '男性が散歩しています。'],
    ['eines', 'Genitive', 'Das ist das Buch eines Freundes.', 'これは友達の本です。'],
    ['einem', 'Dative', 'Ich gebe einem Mann einen Apfel.', '私は男性にりんごをあげます。'],
    ['einen', 'Accusative', 'Ich sehe einen Mann.', '私は男性を見ています。']
] + [
    ['eine', 'Nominative', 'Eine Frau liest ein Buch.', '女性が本を読んでいます。'],
    ['einer', 'Genitive', 'Das ist die Tasche einer Freundin.', 'これは友達のバッグです。'],
    ['einer', 'Dative', 'Ich gebe einer Frau Blumen.', '私は女性に花をあげます。'],
    ['eine', 'Accusative', 'Ich sehe eine Frau.', '私は女性を見ています。']
] + [
    ['ein', 'Nominative', 'Ein Kind spielt im Park.', '中性の子供が公園で遊んでいます。'],
    ['eines', 'Genitive', 'Das ist das Spielzeug eines Kindes.', 'これは子供のおもちゃです。'],
    ['einem', 'Dative', 'Ich gebe einem Kind einen Ball.', '私は子供にボールをあげます。'],
    ['ein', 'Accusative', 'Ich sehe ein Kind.', '私は子供を見ています。']
] + [
    ['keine', 'Nominative', 'Es gibt keine Bücher auf dem Tisch.', 'テーブルの上に本はありません。'],
    ['keiner', 'Genitive', 'Das sind die Taschen keiner Studenten.', 'これは学生たちのかばんではありません。'],
    ['keinen', 'Dative', 'Ich gebe keinen Kindern Süßigkeiten.', '私は子供たちにお菓子をあげません。'],
    ['keine', 'Accusative', 'Ich sehe keine Blumen im Garten.', '庭には花はありません。']
] + [
    ['dieser', 'Nominative', 'Dieser Hund ist groß.', 'この犬は大きいです。'],
    ['dieses', 'Genitive', 'Das ist das Spielzeug dieses Kindes.', 'これはこの子供のおもちゃです。'],
    ['diesem', 'Dative', 'Ich gebe diesem Kind einen Ball.', '私はこの子供にボールをあげます。'],
    ['diesen', 'Accusative', 'Ich sehe diesen Hund.', '私はこの犬を見ています。']
] + [
    ['jene', 'Nominative', 'Jene Frau ist freundlich.', 'あの女性は親切です。'],
    ['jener', 'Genitive', 'Das ist das Buch jener Freundin.', 'これはあの友達の本です。'],
    ['jener', 'Dative', 'Ich gebe jener Frau ein Geschenk.', '私はあの女性にプレゼントをあげます。'],
    ['jene', 'Accusative', 'Ich sehe jene Frau.', '私はあの女性を見ています。']
] + [
    ['solche', 'Nominative', 'Solche Bücher sind interessant.', 'そのような本は面白いです。'],
    ['solcher', 'Genitive', 'Das sind die Taschen solcher Studenten.', 'これはそのような学生たちのかばんです。'],
    ['solchen', 'Dative', 'Ich gebe solchen Kindern Süßigkeiten.', '私はそのような子供たちにお菓子をあげます。'],
    ['solche', 'Accusative', 'Ich sehe solche Blumen im Garten.', '私は庭にそのような花を見ています。']
] + [
    ['jedes', 'Nominative', 'Jedes Kind spielt gerne.', 'どの子供も喜んで遊びます。'],
    ['jedes', 'Genitive', 'Das ist das Spielzeug jedes Kindes.', 'これはどの子供のおもちゃです。'],
    ['jedem', 'Dative', 'Ich gebe jedem Kind einen Ball.', '私はどの子供にボールをあげます。'],
    ['jedes', 'Accusative', 'Ich sehe jedes Kind.', '私はどの子供も見ています。']
]


df = pd.DataFrame(data, columns=['単語', '格変化', '例文', '例文の日本語訳'])

df
# Out:
#          単語         格変化                                       例文  \
# 0       der  Nominative                       Der Hund ist groß.
# 1       der    Genitive           Das ist das Auto der Lehrerin.
# 2       der      Dative          Ich gebe das Buch der Freundin.
# 3       der  Accusative                       Ich sehe den Mann.
# 4       die  Nominative                   Die Blumen sind schön.
# 5       die    Genitive            Das ist das Haus der Familie.
# 6       die      Dative    Ich gebe die Schokolade der Freundin.
# 7       die  Accusative                      Ich sehe die Katze.
# 8       das  Nominative                Das Buch ist interessant.
# 9       das    Genitive             Das ist das Auto des Mannes.
# 10      das      Dative              Ich gebe das Geld dem Kind.
# 11      das  Accusative                    Ich sehe das Mädchen.
# 12      die  Nominative            Die Kinder spielen im Garten.
# ...

# %% [markdown]
# ## [B]基本的な単語
#
# ### 動詞

# %%
data = [
    ['finden', '見つける', 'Ich finde mein Buch nicht.', '私は私の本が見つからない。'],
    ['geben', '与える', 'Kannst du mir bitte dein Handy geben?', 'あなたの携帯をくれませんか？'],
    ['gehen', '行く', 'Jeden Morgen gehe ich zur Arbeit.', '毎朝、私は仕事に行きます。'],
    ['kommen', '来る', 'Wann kommst du nach Hause?', 'いつ家に帰るのですか？'],
    ['machen', 'する、作る', 'Ich möchte eine Pizza machen.', '私はピザを作りたいです。'],
    ['nehmen', '取る', 'Kannst du bitte eine Tasse Kaffee nehmen?', '一杯コーヒーを取ってもらえますか？'],
    ['tun', 'する', 'Was tust du gerade?', '今何をしていますか？']
] + [
    ['bringen', '持ってくる', 'Kannst du bitte die Bücher bringen?', '本を持ってきてくれますか？'],
    ['holen', '取る', 'Ich werde das Paket aus der Post holen.', '私は郵便局からその荷物を取りに行きます。'],
    ['tragen', '運ぶ', 'Kannst du die Einkaufstaschen tragen?', '買い物袋を運んでくれますか？'],
    ['suchen', '探す', 'Ich suche meine Schlüssel.', '私は鍵を探しています。'],
    ['zeigen', '示す', 'Kannst du mir den Weg zum Bahnhof zeigen?', '駅への道を教えてくれますか？'],
    ['stehen', '立つ', 'Bitte stehen Sie auf, wenn der Zug einfährt.', '列車が到着するときは立ってください。'],
    ['liegen', '横になる、置かれている', 'Die Schlüssel liegen auf dem Tisch.', '鍵はテーブルの上に置かれています。'],
    ['sitzen', '座る', 'Können Sie bitte hier sitzen?', 'ここに座っていただけますか？'],
    ['sehen', '見る', 'Ich sehe mir gerne Filme an.', '私は映画を見るのが好きです。'],
    ['hören', '聞く', 'Kannst du mich gut hören?', '私の声がよく聞こえますか？'],
    ['sagen', '言う', 'Was möchtest du mir sagen?', '私に何を言いたいのですか？'],
    ['fragen', '尋ねる', 'Ich möchte dich etwas fragen.', 'あなたに何か質問があります。'],
    ['essen', '食べる', 'Wir können gemeinsam zu Abend essen.', '一緒に夕食をとることができます。'],
    ['trinken', '飲む', 'Möchtest du etwas zu trinken?', '何か飲み物は欲しいですか？'],
    ['singen', '歌う', 'Sie singt gerne im Chor.', '彼女は合唱で歌うのが好きです。'],
    ['spielen', '遊ぶ、演奏する', 'Kinder spielen im Park.', '子供たちは公園で遊んでいます。']
] + [
    ['sprechen', '話す', 'Ich kann Deutsch sprechen.', '私はドイツ語を話すことができます。'],
    ['reden', '話す', 'Lass uns später reden.', '後で話しましょう。'],
    ['denken', '考える', 'Was denkst du darüber?', 'それについてどう思いますか？'],
    ['glauben', '信じる', 'Ich glaube an dich.', '私はあなたを信じています。'],
    ['meinen', '意味する、考える', 'Was genau meinen Sie damit?', 'それは具体的に何を意味しますか？'],
    ['wissen', '知っている', 'Ich weiß nicht, wie es passiert ist.', 'それがどうして起こったのか私は知りません。'],
    ['kennen', '知っている、理解している', 'Ich kenne diese Person nicht.', '私はその人を知りません。'],
    ['lehren', '教える', 'Lehrer können viel lehren.', '教師はたくさん教えることができます。'],
    ['lernen', '学ぶ', 'Ich lerne gerne neue Dinge.', '私は新しいことを学ぶのが好きです。'],
    ['studieren', '勉強する', 'Ich studiere Biologie an der Universität.', '私は大学で生物学を勉強しています。'],
    ['lesen', '読む', 'Ich lese gerne Bücher.', '私は本を読むのが好きです。'],
    ['schreiben', '書く', 'Er kann gut schreiben.', '彼は上手に書けます。'],
    ['rechnen', '計算する', 'Kinder lernen in der Schule rechnen.', '子供たちは学校で計算を学びます。'],
    ['merken', '覚える', 'Kannst du dir das merken?', 'それを覚えておけますか？'],
    ['raten', '勧める、アドバイスする', 'Kannst du mir raten, was ich tun soll?', '私にどうすべきかアドバイスできますか？']
] + [
    ['laufen', '走る', 'Ich laufe gerne im Park.', '私は公園で走るのが好きです。'],
    ['schwimmen', '泳ぐ', 'Im Sommer schwimmen wir oft im See.', '夏になるとよく湖で泳ぎます。'],
    ['springen', '跳ぶ', 'Die Kinder springen über die Pfützen.', '子供たちは水たまりを飛び越えます。'],
    ['tanzen', '踊る', 'Wir werden heute Abend tanzen gehen.', '今夜は踊りに行くつもりです。'],
    ['wandern', 'ハイキングする', 'Am Wochenende wandern wir in den Bergen.', '週末には山でハイキングします。'],
    ['fangen', '捕まえる', 'Kannst du den Ball fangen?', 'ボールを捕まえてくれますか？'],
    ['greifen', 'つかむ', 'Er konnte den Ast gerade noch greifen.', '彼はかろうじてその枝をつかむことができました。'],
    ['haben', '持っている、ある', 'Ich habe einen Hund.', '私は犬を飼っています。'],
    ['klopfen', 'ノックする', 'Jemand klopft an der Tür.', '誰かがドアをノックしています。'],
    ['schlagen', '打つ', 'Der Boxer schlägt seinen Gegner.', 'ボクサーは相手を打つ。'],
    ['werfen', '投げる', 'Wir können den Ball weit werfen.', '私たちはボールを遠くに投げることができます。'],
    ['oeffnen', '開ける', 'Kannst du bitte das Fenster öffnen?', '窓を開けてくれますか？'],
    ['schliessen', '閉める', 'Vergiss nicht, die Tür zu schließen.', 'ドアを閉めるのを忘れないでください。'],
    ['ziehen', '引く', 'Sie zieht den Koffer hinter sich her.', '彼女はスーツケースを引きずっています。']
] + [
    ['fahren', '運転する、乗る', 'Ich fahre jeden Tag mit dem Zug zur Arbeit.', '私は毎日電車で仕事に通っています。'],
    ['fliegen', '飛ぶ', 'Vögel können fliegen.', '鳥は飛ぶことができます。'],
    ['reisen', '旅行する', 'Im Sommer reisen wir gerne ins Ausland.', '夏になると私たちは海外に旅行するのが好きです。'],
    ['fallen', '落ちる', 'Die Blätter fallen im Herbst von den Bäumen.', '秋になると葉が木から落ちます。'],
    ['fliessen', '流れる', 'Der Fluss fließt durch die Stadt.', '川が町を流れています。'],
    ['sinken', '沈む', 'Die Sonne sinkt langsam am Horizont.', '太陽がゆっくりと地平線に沈んでいます。'],
    ['steigen', '上がる', 'Die Preise für Benzin steigen.', 'ガソリンの価格が上がっています。'],
    ['bleiben', '残る、とどまる', 'Kannst du heute Abend bei mir bleiben?', '今夜、私のところに泊まってくれますか？'],
    ['halten', '止まる、持つ', 'Der Zug hält an der nächsten Station.', '電車は次の駅で止まります。'],
    ['warten', '待つ', 'Wir müssen auf den Bus warten.', 'バスを待たなければなりません。'],
    ['leben', '生きる', 'Menschen leben auf der Erde.', '人々は地球上で生きています。'],
    ['sterben', '死ぬ', 'Alle Menschen werden irgendwann sterben.', 'すべての人はいつか死ぬ運命にあります。'],
    ['wachsen', '成長する', 'Die Pflanzen wachsen im Frühling.', '植物は春に成長します。'],
    ['baden', '入浴する', 'Im Sommer baden die Kinder im Pool.', '夏になると子供たちはプールで泳ぎます。'],
    ['putzen', '掃除する', 'Jeden Samstag putze ich mein Zimmer.', '毎週土曜日に私は自分の部屋を掃除します。'],
    ['wohnen', '住む', 'Ich wohne in einer kleinen Stadt.', '私は小さな町に住んでいます。'],
    ['schlafen', '寝る', 'Ich schlafe acht Stunden pro Nacht.', '私は一晩に8時間寝ます。'],
    ['kochen', '料理する', 'Heute Abend koche ich Pasta.', '今夜はパスタを作ります。']
] + [
    ['begegnen', '出会う', 'Ich habe gestern einen alten Freund gestern begegnet.', '昨日、古い友達に出会いました。'],
    ['treffen', '会う、出会う', 'Lass uns morgen treffen.', '明日、会おう。'],
    ['grüßen', '挨拶する', 'Grüß Gott! Wie geht es Ihnen?', 'こんにちは！お元気ですか？'],
    ['schenken', '贈る', 'Ich schenke dir ein Buch zum Geburtstag.', '誕生日に本をプレゼントします。'],
    ['bitten', '頼む', 'Kann ich dich um einen Gefallen bitten?', 'お願いがあって、お願いしてもいいですか？'],
    ['danken', '感謝する', 'Ich danke Ihnen für Ihre Hilfe.', '助けていただきありがとうございます。'],
    ['folgen', '従う', 'Bitte folgen Sie mir.', '私に従ってください。'],
    ['führen', '導く、リードする', 'Der Lehrer führt die Schüler auf Exkursionen.', '先生は生徒たちを遠足に導きます。'],
    ['helfen', '助ける', 'Kannst du mir bitte helfen?', '助けてくれませんか？'],
    ['heißen', '呼ぶ、名前が～である', 'Wie heißt du?', 'あなたの名前は何ですか？'],
    ['nennen', '呼ぶ、名付ける', 'Man nennt ihn den König der Tiere.', '彼は動物の王と呼ばれています。'],
    ['rufen', '呼ぶ、叫ぶ', 'Der Lehrer ruft die Namen der Schüler.', '先生は生徒たちの名前を呼びます。'],
    ['heiraten', '結婚する', 'Sie werden nächstes Jahr heiraten.', '彼らは来年結婚する予定です。'],
    ['küssen', 'キスする', 'Sie küssten sich am Flughafen.', '彼らは空港でキスをしました。'],
    ['lieben', '愛する', 'Ich liebe meine Familie.', '私は家族を愛しています。'],
    ['handeln', '行動する、取引する', 'In kritischen Situationen richtig handeln ist wichtig.', '危機的な状況で適切に行動することは重要です。'],
    ['kaufen', '買う', 'Ich möchte ein neues Buch kaufen.', '新しい本を買いたいです。'],
    ['zahlen', '支払う', 'Kann ich bitte mit Kreditkarte zahlen?', 'クレジットカードで支払ってもいいですか？'],
    ['kosten', '費用がかかる、味がする', 'Wie viel kostet das Kleid? Es kostet 50 Euro.', 'そのドレスはいくらですか？50ユーロです。']
] + [
    ['binden', '結ぶ', 'Sie bindet ihre Haare mit einem Band.', '彼女は髪をリボンで結びます。'],
    ['loesen', '解く、緩める', 'Kannst du das Knoten lösen?', 'その結び目を解いてくれますか？'],
    ['brechen', '壊れる、折れる', 'Das Glas bricht, wenn es fällt.', 'ガラスは落ちると割れます。'],
    ['schaffen', '作り上げる、達成する', 'Ich kann das Projekt schaffen.', '私はそのプロジェクトを達成できるでしょう。'],
    ['bauen', '建てる、作る', 'Wir wollen ein Haus bauen.', '私たちは家を建てたいです。'],
    ['hängen', '吊るす、掛ける', 'Das Bild hängt an der Wand.', 'その絵は壁にかかっています。'],
    ['legen', '置く', 'Bitte leg das Buch auf den Tisch.', 'その本をテーブルに置いてください。'],
    ['setzen', '置く、座る', 'Sie setzt sich auf den Stuhl.', '彼女は椅子に座ります。'],
    ['stellen', '置く、立てる', 'Kannst du die Blumen in die Vase stellen?', '花瓶に花を入れてもらえますか？'],
    ['schicken', '送る', 'Ich schicke dir eine E-Mail.', '私はあなたにメールを送ります。'],
    ['senden', '送る', 'Der Radiosender sendet Musik.', 'そのラジオ局は音楽を送信しています。'],
    ['schneiden', '切る', 'Sie schneidet das Gemüse für das Abendessen.', '彼女は夕食のために野菜を切っています。'],
    ['teilen', '分ける、共有する', 'Wir können die Kosten teilen.', 'コストを分けることができます。'],
    ['trennen', '分ける、切り離す', 'Man sollte Müll von Papier trennen.', 'ゴミと紙を分けるべきです。'],
    ['brauchen', '必要とする', 'Ich brauche Hilfe bei dieser Aufgabe.', 'この課題には助けが必要です。'],
    ['gewinnen', '勝つ、獲得する', 'Das Team hat das Spiel gewonnen.', 'そのチームは試合に勝ちました。'],
    ['leihen', '借りる', 'Kann ich mir dein Buch leihen?', 'あなたの本を借りてもいいですか？'],
    ['verlieren', '失う、負ける', 'Leider haben wir das Spiel verloren.', '残念ながら私たちは試合に負けました。'],
    ['fühlen', '感じる', 'Ich fühle Freude, wenn ich tanze.', '踊るときに私は喜びを感じます。'],
    ['schmecken', '味がする', 'Die Suppe schmeckt sehr gut.', 'そのスープはとてもおいしいです。']
] + [
    ['freuen', '喜ぶ', 'Ich freue mich auf das Wochenende.', '週末を楽しみにしています。'],
    ['fürchten', '恐れる', 'Man sollte sich vor Gefahren fürchten.', '危険を恐れるべきです。'],
    ['hassen', '憎む', 'Hass führt zu Konflikten.', '憎しみは紛争を引き起こします。'],
    ['hoffen', '望む', 'Ich hoffe, dass es morgen schönes Wetter gibt.', '明日は良い天気になることを願っています。'],
    ['wünschen', '願う、希望する', 'Ich wünsche dir viel Erfolg!', '成功を願っています！'],
    ['treiben', '追いやる、行う', 'Sport treiben ist wichtig für die Gesundheit.', 'スポーツをすることは健康にとって重要です。'],
    ['erinnern', '思い出す', 'Ich kann mich gut an meine Kindheit erinnern.', '私は自分の子供時代をよく覚えています。'],
    ['interessieren', '興味を持たせる', 'Dieses Buch interessiert mich sehr.', 'この本は私にとって非常に興味深いです。'],
    ['lächeln', '微笑む', 'Sie lächelte, als sie die Überraschung sah.', '彼女は驚きを見て微笑んだ。'],
    ['lachen', '笑う', 'Das lustige Video ließ uns alle lachen.', 'その面白いビデオでみんな笑いました。'],
    ['weinen', '泣く', 'Manchmal muss man weinen, um sich besser zu fühlen.', '時々、気分を良くするために泣く必要があります。'],
    ['beginnen', '始まる', 'Der Film beginnt in zehn Minuten.', '映画は10分後に始まります。'],
    ['geschehen', '起こる、行われる', 'Das Unglück geschieht oft unerwartet.', '災難はよく予期せずに起こります。'],
    ['gelingen', '成功する', 'Der Plan ist gelungen.', '計画は成功しました。'],
    ['fehlen', '欠けている、不足している', 'Du fehlst mir sehr.', 'あなたがとても恋しいです。'],
    ['stecken', '挿す、詰まる', 'Der Schlüssel steckt im Schloss.', '鍵は錠前に挿してあります。'],
    ['brennen', '燃える', 'Die Kerzen brennen während der Zeremonie.', 'ろうそくは儀式中に燃えています。'],
    ['regnen', '雨が降る', 'Es wird morgen den ganzen Tag regnen.', '明日は一日中雨が降りそうです。'],
    ['scheinen', '輝く、見える', 'Die Sonne scheint am Himmel.', '太陽が空に輝いています。']
]

df = pd.DataFrame(data, columns=['単語', '日本語訳', '例文', '例文の日本語訳'])
print(df.head())
# Out:
#        単語   日本語訳                                     例文         例文の日本語訳
# 0  finden   見つける             Ich finde mein Buch nicht.   私は私の本が見つからない。
# 1   geben    与える  Kannst du mir bitte dein Handy geben?  あなたの携帯をくれませんか？
# 2   gehen     行く      Jeden Morgen gehe ich zur Arbeit.   毎朝、私は仕事に行きます。
# 3  kommen     来る             Wann kommst du nach Hause?     いつ家に帰るのですか？
# 4  machen  する、作る          Ich möchte eine Pizza machen.    私はピザを作りたいです。

# %%
df
# Out:
#                 単語          日本語訳  \
# 0           finden          見つける
# 1            geben           与える
# 2            gehen            行く
# 3           kommen            来る
# 4           machen         する、作る
# 5           nehmen            取る
# 6              tun            する
# 7          bringen         持ってくる
# 8            holen            取る
# 9           tragen            運ぶ
# 10          suchen            探す
# 11          zeigen            示す
# 12          stehen            立つ
# 13          liegen   横になる、置かれている
# 14          sitzen            座る
# 15           sehen            見る
# 16           hören            聞く
# 17           sagen            言う
# 18          fragen           尋ねる
# 19           essen           食べる
# 20         trinken            飲む
# 21          singen            歌う
# 22         spielen       遊ぶ、演奏する
# 23        sprechen            話す
# 24           reden            話す
# 25          denken           考える
# 26         glauben           信じる
# ...

# %%
df.sort_values(by='単語')
# Out:
#                 単語          日本語訳  \
# 65           baden          入浴する
# 93           bauen        建てる、作る
# 70        begegnen           出会う
# 120       beginnen           始まる
# 89          binden            結ぶ
# 74          bitten            頼む
# 59         bleiben       残る、とどまる
# 103       brauchen         必要とする
# 91         brechen       壊れる、折れる
# 125        brennen           燃える
# 7          bringen         持ってくる
# 75          danken          感謝する
# 25          denken           考える
# 115       erinnern          思い出す
# 19           essen           食べる
# 52          fahren       運転する、乗る
# 55          fallen           落ちる
# 43          fangen          捕まえる
# 123         fehlen  欠けている、不足している
# 0           finden          見つける
# 53         fliegen            飛ぶ
# 56        fliessen           流れる
# 76          folgen            従う
# 18          fragen           尋ねる
# 109         freuen            喜ぶ
# 107         fühlen           感じる
# 77          führen      導く、リードする
# ...
